# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['axes.unicode_minus'] = False
plt.rc('font', family='NanumGothicCoding')
sns.set(font='NanumGothicCoding')

# %%
pl_20_21 = pd.read_csv('./data/PL 20-21.csv').sort_values("Final_Rank")
pl_21_22 = pd.read_csv('./data/PL 21-22.csv').sort_values("Final_Rank")
pl_22_23 = pd.read_csv('./data/PL 22-23.csv').sort_values("Final_Rank")
pl_23_24 = pd.read_csv('./data/PL 23-24.csv').sort_values("Final_Rank")
pl_24_25 = pd.read_csv('./data/PL 24-25.csv').sort_values("Final_Rank")

# %%
major_european_clubs_20_21 = pd.read_csv('./data/Major European Clubs 20-21.csv')
major_european_clubs_21_22 = pd.read_csv('./data/Major European Clubs 21-22.csv')
major_european_clubs_22_23 = pd.read_csv('./data/Major European Clubs 22-23.csv')
major_european_clubs_23_24 = pd.read_csv('./data/Major European Clubs 23-24.csv')
major_european_clubs_24_25 = pd.read_csv('./data/Major European Clubs 24-25.csv')

# %%
pl_20_21.head()
# Out:
#      Season               Club  Expenditure_EUR_m  Income_EUR_m  \
# 11  2020-21    Manchester City             173.40         64.00
# 12  2020-21  Manchester United              83.95         19.50
# 10  2020-21       Liverpool FC              84.80         17.20
# 4   2020-21         Chelsea FC             267.20         57.15
# 9   2020-21     Leicester City              59.40         53.77
#
#     Net_Balance_EUR_m  Final_Rank
# 11            -109.40           1
# 12             -64.45           2
# 10             -67.60           3
# 4             -210.05           4
# 9               -5.63           5

# %% [markdown]
# ## 각 시즌 별 이적료 지출

# %% [markdown]
# ### 20-21 시즌

# %%
sns.barplot(x='Expenditure_EUR_m', y='Club', data=pl_20_21)
plt.title('2020-21 PL 팀별 이적료 지출')
plt.xlabel('이적료(단위 1,000,000)')
plt.ylabel('팀 (성적 순)')
plt.show()

# %%
sns.barplot(x='Expenditure_EUR_m', y='Club', data=major_european_clubs_20_21)
plt.title('2020-21 유럽 주요 팀별 이적료 지출')
plt.xlabel('이적료(단위 1,000,000)')
plt.ylabel('팀 (성적 순)')
plt.show()

# %% [markdown]
# ### 21-22 시즌

# %%
sns.barplot(x='Expenditure_EUR_m', y='Club', data=pl_21_22)
plt.title('2021-22 PL 팀별 이적료 지출')
plt.xlabel('이적료(단위 1,000,000)')
plt.ylabel('팀 (성적 순)')
plt.show()

# %%
sns.barplot(x='Expenditure_EUR_m', y='Club', data=major_european_clubs_21_22)
plt.title('2021-22 유럽 주요 팀별 이적료 지출')
plt.xlabel('이적료(단위 1,000,000)')
plt.ylabel('팀 (성적 순)')
plt.show()

# %% [markdown]
# ### 22-23 시즌

# %%
sns.barplot(x='Expenditure_EUR_m', y='Club', data=pl_22_23)
plt.title('2022-23 PL 팀별 이적료 지출')
plt.xlabel('이적료(단위 1,000,000)')
plt.ylabel('팀 (성적 순)')
plt.show()

# %%
sns.barplot(x='Expenditure_EUR_m', y='Club', data=major_european_clubs_22_23)
plt.title('2022-23 유럽 주요 팀별 이적료 지출')
plt.xlabel('이적료(단위 1,000,000)')
plt.ylabel('팀 (성적 순)')
plt.show()

# %% [markdown]
# ### 23-24 시즌

# %%
sns.barplot(x='Expenditure_EUR_m', y='Club', data=pl_23_24)
plt.title('2023-24 PL 팀별 이적료 지출')
plt.xlabel('이적료(단위 1,000,000)')
plt.ylabel('팀 (성적 순)')
plt.show()

# %%
sns.barplot(x='Expenditure_EUR_m', y='Club', data=major_european_clubs_23_24)
plt.title('2023-24 유럽 주요 팀별 이적료 지출')
plt.xlabel('이적료(단위 1,000,000)')
plt.ylabel('팀 (성적 순)')
plt.show()

# %% [markdown]
# ### 24-25 시즌

# %%
sns.barplot(x='Expenditure_EUR_m', y='Club', data=pl_24_25)
plt.title('2024-25 PL 팀별 이적료 지출')
plt.xlabel('이적료(단위 1,000,000)')
plt.ylabel('팀 (성적 순)')
plt.show()

# %%
sns.barplot(x='Expenditure_EUR_m', y='Club', data=major_european_clubs_24_25)
plt.title('2024-25 유럽 주요 팀별 이적료 지출')
plt.xlabel('이적료(단위 1,000,000)')
plt.ylabel('팀 (성적 순)')
plt.show()

# %% [markdown]
# - 단순히 이적료를 많이 쓴다고 해서 성적이 무조건 나오지는 않음
#     - 기존 스쿼드의 차이를 고려해야함
#         - 승격팀의 경우 기존 스쿼드의 질이 낮으므로 많은 돈을 써서 스쿼드를 보강해야함
#         - 하지만 기존 스쿼드의 한계로 인해 낮은 순위를 얻는 경우가 많음
#     - 이적료를 많이 쓴다는 것은 기존 스쿼드에 보강할 부분이 많았다는 뜻으로 볼 수 있을듯
#         - 23-24 첼시, 24-25 맨체스터 유나이티드는 지난 시즌 부진한 성적으로 다음 시즌에 많은 영입을 수행
#     - 기존 선수들의 계약 만료 시기도 고려
#         - 기존 선수들(특히 주요 선수)의 계약이 만료가 될 경우 해당 선수를 대체할 선수를 영입해야하므로 해당 시즌에 많은 이적료 지출이 발생할 수 있음
#     - 팀 간의 위상 별 이적료 차이도 발생
#         - 팀 위상이 낮을 경우 선수가 선호하지 않음 → 이적료 ↑

# %% [markdown]
# ## 각 시즌 별 이적료 수익

# %% [markdown]
# ### 20-21 시즌

# %%
sns.barplot(x='Income_EUR_m', y='Club', data=pl_20_21)
plt.title('2020-21 PL 팀별 이적료 수익')
plt.xlabel('이적료(단위 1,000,000)')
plt.ylabel('팀 (성적 순)')
plt.show()

# %%
sns.barplot(x='Income_EUR_m', y='Club', data=major_european_clubs_20_21)
plt.title('2020-21 유럽 주요 팀별 이적료 수익')
plt.xlabel('이적료(단위 1,000,000)')
plt.ylabel('팀 (성적 순)')
plt.show()

# %% [markdown]
# ### 21-22 시즌

# %%
sns.barplot(x='Income_EUR_m', y='Club', data=pl_21_22)
plt.title('2021-22 PL 팀별 이적료 수익')
plt.xlabel('이적료(단위 1,000,000)')
plt.ylabel('팀 (성적 순)')
plt.show()

# %%
sns.barplot(x='Income_EUR_m', y='Club', data=major_european_clubs_21_22)
plt.title('2021-22 유럽 주요 팀별 이적료 수익')
plt.xlabel('이적료(단위 1,000,000)')
plt.ylabel('팀 (성적 순)')
plt.show()

# %% [markdown]
# ### 22-23 시즌

# %%
sns.barplot(x='Income_EUR_m', y='Club', data=pl_22_23)
plt.title('2022-23 PL 팀별 이적료 수익')
plt.xlabel('이적료(단위 1,000,000)')
plt.ylabel('팀 (성적 순)')
plt.show()

# %%
sns.barplot(x='Income_EUR_m', y='Club', data=major_european_clubs_20_21)
plt.title('2022-23 유럽 주요 팀별 이적료 수익')
plt.xlabel('이적료(단위 1,000,000)')
plt.ylabel('팀 (성적 순)')
plt.show()

# %% [markdown]
# ### 23-24 시즌

# %%
sns.barplot(x='Income_EUR_m', y='Club', data=pl_23_24)
plt.title('2023-24 PL 팀별 이적료 수익')
plt.xlabel('이적료(단위 1,000,000)')
plt.ylabel('팀 (성적 순)')
plt.show()

# %%
sns.barplot(x='Income_EUR_m', y='Club', data=major_european_clubs_23_24)
plt.title('2023-24 유럽 주요 팀별 이적료 수익')
plt.xlabel('이적료(단위 1,000,000)')
plt.ylabel('팀 (성적 순)')
plt.show()

# %% [markdown]
# ### 24-25 시즌

# %%
sns.barplot(x='Income_EUR_m', y='Club', data=pl_24_25)
plt.title('2024-25 PL 팀별 이적료 수익')
plt.xlabel('이적료(단위 1,000,000)')
plt.ylabel('팀 (성적 순)')
plt.show()

# %%
sns.barplot(x='Income_EUR_m', y='Club', data=major_european_clubs_24_25)
plt.title('2024-25 유럽 주요 팀별 이적료 수익')
plt.xlabel('이적료(단위 1,000,000)')
plt.ylabel('팀 (성적 순)')
plt.show()

# %% [markdown]
# - 단순히 이적료 수익이 높다고 성적이 낮아지고, 이적료 수익이 낮다고 성적이 높아지는 것은 아님
#     - 22-23 시즌에 가장 많은 수익을 본 맨체스터 시티는 해당 시즌 유러피안 트레블(자국 챔피언 & 유럽 챔피언 & 자국 토너먼트 대회 동시 우승)을 달성
#     - 경쟁이 치열한 PL 특성 상 중하위권 팀들도 단순히 이적료 수익만을 위해서 선수를 판매할 수 없음
# - 대체적으로 많은 돈을 쓴 팀이 수익도 높음
#     - 비싼 선수를 사고, 비싼 선수를 파는 팀이 지출과 수익 모두 높을 수 밖에 없음
# - 팀 간의 이적 시장 전략에 따른 차이도 존재
#     - 스포르팅, 벤피카, 아약스 등의 클럽은 꾸준히 유망주 선수를 배출하여 유럽 주요 리그에 판매하는 전략을 사용
#     - 해당 팀들은 자국 리그에서는 항상 우승 후보에 있지만 유럽 전체에서는 16강 or 8강 정도의 기대치를 가지는 팀

# %% [markdown]
# ## 각 시즌 별 이적료 총합

# %%
def create_net_balance_plot(data, season, title):
    data_sorted = data.sort_values("Final_Rank", ascending=False)
    
    colors = ['red' if x < 0 else 'blue' for x in data_sorted['Net_Balance_EUR_m']]

    bars = plt.barh(data_sorted['Club'], data_sorted['Net_Balance_EUR_m'], color=colors)

    plt.title(f'{title}')
    plt.xlabel('이적료(단위 1,000,000)')
    plt.ylabel('팀 (성적 순)')

    plt.axvline(x=0, color='black', linestyle='-', alpha=0.5, linewidth=1)
    
    plt.show()

# %% [markdown]
# ### 20-21 시즌

# %%
create_net_balance_plot(pl_20_21, '2020-21', '2020-21 PL 팀별 이적료 총합')

# %%
create_net_balance_plot(major_european_clubs_20_21, '2020-21', '2020-21 유럽 주요 팀별 이적료 총합')

# %% [markdown]
# ### 21-22 시즌

# %%
create_net_balance_plot(pl_21_22, '2021-22', '2021-22 PL 팀별 이적료 총합')

# %%
create_net_balance_plot(major_european_clubs_21_22, '2021-22', '2021-22 유럽 주요 팀별 이적료 총합')

# %% [markdown]
# ### 22-23 시즌

# %%
create_net_balance_plot(pl_22_23, '2022-23', '2022-23 PL 팀별 이적료 총합')

# %%
create_net_balance_plot(major_european_clubs_22_23, '2022-23', '2022-23 유럽 주요 팀별 이적료 총합')

# %% [markdown]
# ### 23-24 시즌

# %%
create_net_balance_plot(pl_23_24, '2023-24', '2023-24 PL 팀별 이적료 총합')

# %%
create_net_balance_plot(major_european_clubs_23_24, '2023-24', '2023-24 유럽 주요 팀별 이적료 총합')

# %% [markdown]
# ### 24-25 시즌

# %%
create_net_balance_plot(pl_24_25, '2024-25', '2024-25 PL 팀별 이적료 총합')

# %%
create_net_balance_plot(major_european_clubs_24_25, '2024-25', '2024-25 유럽 주요 팀별 이적료 총합')

# %% [markdown]
# - 중계권료가 세계 최고 수준인 PL 팀들은 이적시장에서 대체로 많은 돈을 지출
#     - 이적 시장에서 이익을 보는 것보다 PL에서 생존을 해서 볼 수 있는 이득이 더 크다고 보는 것 같음
#     - 다른 유럽의 주요 팀들과 비교해도 밀리지 않음
# - PL 하위권 팀들이 많은 돈을 쓴다고 해서 유럽의 강팀들과 대등한 수준은 아니다
#     - 단순히 돈을 많이 쓴다고 해서 무조건적으로 좋은 스쿼드를 갖추고 좋은 성적을 낼 수는 없다
#     - 팀의 위상 차이, 유스 시스템, 팀의 매니지먼트 등 많은 부분에서 팀의 전력이 좌우된다

# %% [markdown]
# ## 총평
#
# - 단순히 이적시장의 데이터만으로 팀의 전력을 측정하기는 힘들다
#     - 부상, 영입 & 방출의 유형(유망주 or 즉전감 영입의 차이, 완전 이적 or 임대 이적), 감독의 역량 등 너무 많은 변수가 존재
#     - 실제로 24-25 시즌의 노팅엄 포레스트, 데이터에는 없지만 15-16 시즌의 레스터 시티 등 빈약한 재정 상황에서도 좋은 성적을 내는 경우가 가끔 존재
# - PL 팀들은 전체적으로 이적 시장에서 매우 많은 돈을 쓴다
#     - 세계에서 경쟁이 가장 치열한 리그답게 이적 시장에서 선수를 판매해 이득을 보기보다는 생존을 위한 선택을 함
#     - 또한 PL 하위권 팀들도 유럽의 주요 팀들에 비해서 밀리지 않는 지출을 한다
#     - 하지만 PL 하위권 팀들이 유럽 주요 팀들만큼 돈을 쓴다고 해서 그 팀들과 비슷한 전력이라고 보기는 힘들다
# - 한 시즌의 이적 시장이 아닌 장기간의 이적 시장으로 보면 좀 더 뚜렷한 전력 차이를 볼 수 있을 수도 있을 것이다
#     - 한 시즌에 바꿀 수 있는 선수는 보통 3~4명 정도이지만 축구는 경기에 뛰는 선수만 11명이고 후보 선수들까지 포함하면 20명이 넘어간다
#     - 한 시즌만으로 팀의 많은 것들을 바꿀 수 없다
#     - 하지만 기간이 길어지면 장기적으로 많은 지출을 하는 팀이 좋은 성적을 낼것은 자명하다
#     - 실제로 빅 6팀들은 장기간 많은 돈을 쓰고 스쿼드의 질을 유지하거나 높이기 위한 노력을 한다
# - 돈만으로 성적을 살 수는 없다. 그렇다고 돈 없이 성적을 살 수 있다는 뜻은 아니다
#     - 돈만으로 성적을 살 수 있는 것은 아니다
#     - 실제로 맨체스터 유나이티드는 항상 많은 돈을 쓰지만 지난 시즌 리그 15위, 현재는 16위에 머물러있다
#     - 하지만 돈 없이는 장기적으로 좋은 성적을 내는 것은 힘들다
#     - 여러 요소가 겹쳐 짧은 기간 동안 좋은 성적을 낼 수는 있지만 결국 장기적으로 보면 꾸준히 선수를 수급하지 못하면 성적이 내려갈 수 밖에 없다
#     - 결국 일부 팀들만이 상위권을 독점하는 것은 자본주의 원리에 의한 차이가 축구라는 스포츠에서도 유의미함을 증명한다
